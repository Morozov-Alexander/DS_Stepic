# %%
import pandas as pd
import numpy as np
dota_hero_stats = pd.read_csv('dota_hero_stats.csv')
dota_hero_stats
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
(dota_hero_stats.legs == 8).sum()
# Out:
# 1

# %%
dota_hero_stats['legs'].value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
dota_hero_stats.aggregate({'legs': 'value_counts'}).sort_index()
# Out:
#    legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1

# %%
df.groupby(['attack_type','primary_attr']).size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-f47640ccc0c5> in <module>
# ----> 1 df.groupby(['attack_type','primary_attr']).size()
#       2
#
# NameError: name 'df' is not defined

# %%
dota_hero_stats.groupby(['attack_type','primary_attr']).size()
# Out:
# attack_type  primary_attr
# Melee        agi             19
#              int              2
#              str             35
# Ranged       agi             18
#              int             40
#              str              3
# dtype: int64

# %%
dota_hero_stats.groupby('legs').size()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
dota_hero_stats.groupby(['legs']).id.nunique()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# Name: id, dtype: int64

# %%
ds = pd.read_csv('accountancy.csv')
ds
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
ds.groupby(['Executor','Type']).max()['Salary'].unstack()
# Out:
# Type        A    B    C    D    E    F
# Executor
# Loopa      58  249  249  181  220  244
# Pupa      234   77   94  194  197  195

# %%
df = pd.read_csv('algae.csv')
df
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
df.query("genus == 'Fucus'").aggregate({'alanin': 'max','alanin': 'mean','alanin': 'min' })
# Out:
# alanin    0.346431
# dtype: float64

# %%
df.groupby('group')['citrate'].var().loc['red']
# Out:
# nan

# %%
df.groupby('group').aggregate({'sucrose': lambda x: max(x) - min(x)})
# Out:
#         sucrose
# group
# brown  5.189345
# green  3.259662
# red    0.000000

# %%
df.groupby('group').aggregate(['count', 'var', np.ptp]).transpose()
# Out:
# group                brown     green  red
# sucrose    count  6.000000  3.000000  1.0
#            var    5.459098  2.672626  NaN
#            ptp    5.189345  3.259662  0.0
# alanin     count  6.000000  3.000000  1.0
#            var    7.220351  7.059917  NaN
#            ptp    6.294872  5.232574  0.0
# citrate    count  6.000000  3.000000  1.0
#            var    5.468942  3.950113  NaN
#            ptp    5.351686  3.857763  0.0
# glucose    count  6.000000  3.000000  1.0
#            var    1.767756  0.266265  NaN
#            ptp    3.740495  1.026753  0.0
# oleic_acid count  6.000000  3.000000  1.0
#            var    4.385233  0.540388  NaN
#            ptp    6.100592  1.396502  0.0
